# %% [markdown]
# ## **1. Load library**

# %%
import pandas as pd
from pycaret.regression import *

# %% [markdown]
# ## **2. Load dataset**

# %%
raw = pd.read_csv('./models/solubility/delaney_solubility_descriptors.csv')
sol_desc = raw
sol_desc
# Out:
#          LogP   Mol Wt  Num Rotatable Bonds  Aromatic Proportion   logS
# 0     2.59540  167.850                  0.0             0.000000 -2.180
# 1     2.37650  133.405                  0.0             0.000000 -2.000
# 2     2.59380  167.850                  1.0             0.000000 -1.740
# 3     2.02890  133.405                  1.0             0.000000 -1.480
# 4     2.91890  187.375                  1.0             0.000000 -3.040
# ...       ...      ...                  ...                  ...    ...
# 1139  1.98820  287.343                  8.0             0.000000  1.144
# 1140  3.42130  286.114                  2.0             0.333333 -4.925
# 1141  3.60960  308.333                  4.0             0.695652 -3.893
# 1142  2.56214  354.815                  3.0             0.521739 -3.790
# 1143  2.02164  179.219                  1.0             0.461538 -2.581
#
# [1144 rows x 5 columns]

# %% [markdown]
# ## **3. Model Building**

# %% [markdown]
# ### **3.1. Model Setup**

# %%
model = setup(data = sol_desc, target = 'logS', train_size=0.8, silent=True)
# Out:
# <style  type="text/css" >
# </style><table id="T_09485fbe_2ace_11eb_afca_fe017cc00077" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row0_col1" class="data row0 col1" >6399</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row1_col1" class="data row1 col1" >logS</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row2_col1" class="data row2 col1" >(1144, 5)</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row4_col1" class="data row4 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row9_col1" class="data row9 col1" >(915, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row10_col1" class="data row10 col1" >(229, 4)</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_09485fbe_2ace_11eb_afca_fe017cc00077level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_09485fbe_2ace_11eb_afca_fe017cc00077row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th

# %% [markdown]
# ### **3.2. Model comparison**
#
# Training set

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077 th {
#           text-align: left;
#     }#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row0_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row1_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row1_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row1_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row1_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row1_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row1_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row1_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row2_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row2_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row2_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row2_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row2_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row2_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row2_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row3_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row3_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row3_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row3_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row3_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row3_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row3_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row4_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row4_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row4_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row4_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row4_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row4_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row4_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row5_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row5_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row5_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row5_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row5_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row5_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row5_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row6_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row6_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row6_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row6_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row6_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row6_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row6_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row7_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row7_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row7_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row7_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row7_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row7_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row7_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row8_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row8_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row8_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row8_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row8_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row8_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row8_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row9_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row9_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row9_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row9_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row9_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row9_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row9_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row10_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row10_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row10_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row10_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row10_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row10_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row10_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row11_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row11_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row11_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row11_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row11_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row11_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row11_col6,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row12_col0,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row12_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row12_col2,#T_1a8a0c ...
#             text-align:  left;
#             text-align:  left;
#         }#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row0_col1,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row0_col2,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row0_col3,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row0_col4,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row0_col5,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row0_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row1_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row2_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row3_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row4_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row5_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row6_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row7_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row8_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row10_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row11_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row15_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row16_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row17_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row9_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row12_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row13_col7,#T_1a8a0c00_2ace_11eb_aaa0_fe017cc00077row14_col7{
#             text-align:  left;
#             text-align:  left;
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=-1, oob_score=False,
#                     random_state=6399, verbose=0, warm_start=False)

# %% [markdown]
# ### **3.3. Model Creation**

# %%
et = create_model('et')
# Out:
# <style  type="text/css" >
# #T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row10_col0,#T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row10_col1,#T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row10_col2,#T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row10_col3,#T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row10_col4,#T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row10_col5{
#             background:  yellow;
#         }</style><table id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row0_col0" class="data row0 col0" >0.5080</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row0_col1" class="data row0 col1" >0.4889</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row0_col2" class="data row0 col2" >0.6992</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row0_col3" class="data row0 col3" >0.8651</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row0_col4" class="data row0 col4" >0.2212</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row0_col5" class="data row0 col5" >0.3533</td>
#             </tr>
#             <tr>
#                         <th id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row1_col0" class="data row1 col0" >0.5639</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row1_col1" class="data row1 col1" >0.5702</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row1_col2" class="data row1 col2" >0.7551</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row1_col3" class="data row1 col3" >0.8860</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row1_col4" class="data row1 col4" >0.2081</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row1_col5" class="data row1 col5" >1.4680</td>
#             </tr>
#             <tr>
#                         <th id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row2_col0" class="data row2 col0" >0.5311</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row2_col1" class="data row2 col1" >0.6713</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row2_col2" class="data row2 col2" >0.8193</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row2_col3" class="data row2 col3" >0.8655</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row2_col4" class="data row2 col4" >0.2416</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row2_col5" class="data row2 col5" >0.7628</td>
#             </tr>
#             <tr>
#                         <th id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row3_col0" class="data row3 col0" >0.5939</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row3_col1" class="data row3 col1" >0.6929</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row3_col2" class="data row3 col2" >0.8324</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row3_col3" class="data row3 col3" >0.8247</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row3_col4" class="data row3 col4" >0.2433</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row3_col5" class="data row3 col5" >0.9524</td>
#             </tr>
#             <tr>
#                         <th id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row4_col0" class="data row4 col0" >0.5074</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row4_col1" class="data row4 col1" >0.4774</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row4_col2" class="data row4 col2" >0.6910</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row4_col3" class="data row4 col3" >0.8939</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row4_col4" class="data row4 col4" >0.2017</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row4_col5" class="data row4 col5" >0.3353</td>
#             </tr>
#             <tr>
#                         <th id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row5_col0" class="data row5 col0" >0.4016</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row5_col1" class="data row5 col1" >0.3803</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row5_col2" class="data row5 col2" >0.6167</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row5_col3" class="data row5 col3" >0.9082</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row5_col4" class="data row5 col4" >0.1591</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row5_col5" class="data row5 col5" >0.2653</td>
#             </tr>
#             <tr>
#                         <th id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row6_col0" class="data row6 col0" >0.4511</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row6_col1" class="data row6 col1" >0.3984</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row6_col2" class="data row6 col2" >0.6312</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row6_col3" class="data row6 col3" >0.8825</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row6_col4" class="data row6 col4" >0.1743</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row6_col5" class="data row6 col5" >0.4475</td>
#             </tr>
#             <tr>
#                         <th id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row7_col0" class="data row7 col0" >0.5800</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row7_col1" class="data row7 col1" >0.6423</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row7_col2" class="data row7 col2" >0.8014</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row7_col3" class="data row7 col3" >0.8273</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row7_col4" class="data row7 col4" >0.2410</td>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row7_col5" class="data row7 col5" >0.5447</td>
#             </tr>
#             <tr>
#                         <th id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_1be8cb74_2ace_11eb_b5a7_fe017cc00077row8_col0" class="data row8 col0" >0.4434</td>
#                         <td id

# %% [markdown]
# ### **3.4. Model Tuning**
#
# The learning parameters are subjected to optimization at this phase. Here, 50 iterations is used for the optimization process and the fitness function is the Mean Absolute Error (MAE) which is the performance metric used to judge at which learning parameter settings are optimal.

# %%
tuned_et = tune_model(et, n_iter = 50, optimize = 'mae')
# Out:
# <style  type="text/css" >
# #T_4c482400_2ace_11eb_b531_fe017cc00077row10_col0,#T_4c482400_2ace_11eb_b531_fe017cc00077row10_col1,#T_4c482400_2ace_11eb_b531_fe017cc00077row10_col2,#T_4c482400_2ace_11eb_b531_fe017cc00077row10_col3,#T_4c482400_2ace_11eb_b531_fe017cc00077row10_col4,#T_4c482400_2ace_11eb_b531_fe017cc00077row10_col5{
#             background:  yellow;
#         }</style><table id="T_4c482400_2ace_11eb_b531_fe017cc00077" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c482400_2ace_11eb_b531_fe017cc00077level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row0_col0" class="data row0 col0" >0.6115</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row0_col1" class="data row0 col1" >0.6102</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row0_col2" class="data row0 col2" >0.7811</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row0_col3" class="data row0 col3" >0.8316</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row0_col4" class="data row0 col4" >0.2268</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row0_col5" class="data row0 col5" >0.5249</td>
#             </tr>
#             <tr>
#                         <th id="T_4c482400_2ace_11eb_b531_fe017cc00077level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row1_col0" class="data row1 col0" >0.6518</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row1_col1" class="data row1 col1" >0.8082</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row1_col2" class="data row1 col2" >0.8990</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row1_col3" class="data row1 col3" >0.8384</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row1_col4" class="data row1 col4" >0.2492</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row1_col5" class="data row1 col5" >2.4111</td>
#             </tr>
#             <tr>
#                         <th id="T_4c482400_2ace_11eb_b531_fe017cc00077level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row2_col0" class="data row2 col0" >0.6425</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row2_col1" class="data row2 col1" >0.7524</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row2_col2" class="data row2 col2" >0.8674</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row2_col3" class="data row2 col3" >0.8492</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row2_col4" class="data row2 col4" >0.2583</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row2_col5" class="data row2 col5" >0.8466</td>
#             </tr>
#             <tr>
#                         <th id="T_4c482400_2ace_11eb_b531_fe017cc00077level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row3_col0" class="data row3 col0" >0.5992</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row3_col1" class="data row3 col1" >0.6589</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row3_col2" class="data row3 col2" >0.8117</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row3_col3" class="data row3 col3" >0.8333</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row3_col4" class="data row3 col4" >0.2151</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row3_col5" class="data row3 col5" >1.0683</td>
#             </tr>
#             <tr>
#                         <th id="T_4c482400_2ace_11eb_b531_fe017cc00077level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row4_col0" class="data row4 col0" >0.5566</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row4_col1" class="data row4 col1" >0.5596</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row4_col2" class="data row4 col2" >0.7480</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row4_col3" class="data row4 col3" >0.8757</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row4_col4" class="data row4 col4" >0.2148</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row4_col5" class="data row4 col5" >0.3960</td>
#             </tr>
#             <tr>
#                         <th id="T_4c482400_2ace_11eb_b531_fe017cc00077level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row5_col0" class="data row5 col0" >0.5245</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row5_col1" class="data row5 col1" >0.5216</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row5_col2" class="data row5 col2" >0.7222</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row5_col3" class="data row5 col3" >0.8741</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row5_col4" class="data row5 col4" >0.1899</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row5_col5" class="data row5 col5" >0.3888</td>
#             </tr>
#             <tr>
#                         <th id="T_4c482400_2ace_11eb_b531_fe017cc00077level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row6_col0" class="data row6 col0" >0.5785</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row6_col1" class="data row6 col1" >0.6385</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row6_col2" class="data row6 col2" >0.7990</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row6_col3" class="data row6 col3" >0.8118</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row6_col4" class="data row6 col4" >0.2087</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row6_col5" class="data row6 col5" >0.4810</td>
#             </tr>
#             <tr>
#                         <th id="T_4c482400_2ace_11eb_b531_fe017cc00077level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row7_col0" class="data row7 col0" >0.5975</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row7_col1" class="data row7 col1" >0.5562</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row7_col2" class="data row7 col2" >0.7458</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row7_col3" class="data row7 col3" >0.8505</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row7_col4" class="data row7 col4" >0.2172</td>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row7_col5" class="data row7 col5" >0.9009</td>
#             </tr>
#             <tr>
#                         <th id="T_4c482400_2ace_11eb_b531_fe017cc00077level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_4c482400_2ace_11eb_b531_fe017cc00077row8_col0" class="data row8 col0" >0.6093</td>
#                         <td id

# %% [markdown]
# #### **3.4.1 Model Hyperparameter**
#
# #### Model

# %%
plot_model(et, 'parameter')
# Out:
#                          Parameters
# bootstrap                     False
# ccp_alpha                       0.0
# criterion                       mse
# max_depth                      None
# max_features                   auto
# max_leaf_nodes                 None
# max_samples                    None
# min_impurity_decrease           0.0
# min_impurity_split             None
# min_samples_leaf                  1
# min_samples_split                 2
# min_weight_fraction_leaf        0.0
# n_estimators                    100
# n_jobs                           -1
# oob_score                     False
# random_state                   6399
# verbose                           0
# warm_start                    False

# %% [markdown]
# #### Tuned model

# %%
plot_model(tuned_et, 'parameter')
# Out:
#                          Parameters
# bootstrap                     False
# ccp_alpha                       0.0
# criterion                       mae
# max_depth                        11
# max_features                    1.0
# max_leaf_nodes                 None
# max_samples                    None
# min_impurity_decrease         0.001
# min_impurity_split             None
# min_samples_leaf                  6
# min_samples_split                 5
# min_weight_fraction_leaf        0.0
# n_estimators                    300
# n_jobs                           -1
# oob_score                     False
# random_state                   6399
# verbose                           0
# warm_start                    False

# %% [markdown]
# ## **4. Testing**
#
# Apply the trained model (built with 80% subset) to evaluate on the testing set.

# %%
prediction_holdout = predict_model(et)
# Out:
# <style  type="text/css" >
# </style><table id="T_4cbb99b8_2ace_11eb_af54_fe017cc00077" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4cbb99b8_2ace_11eb_af54_fe017cc00077level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4cbb99b8_2ace_11eb_af54_fe017cc00077row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#                         <td id="T_4cbb99b8_2ace_11eb_af54_fe017cc00077row0_col1" class="data row0 col1" >0.5614</td>
#                         <td id="T_4cbb99b8_2ace_11eb_af54_fe017cc00077row0_col2" class="data row0 col2" >0.5188</td>
#                         <td id="T_4cbb99b8_2ace_11eb_af54_fe017cc00077row0_col3" class="data row0 col3" >0.7203</td>
#                         <td id="T_4cbb99b8_2ace_11eb_af54_fe017cc00077row0_col4" class="data row0 col4" >0.8866</td>
#                         <td id="T_4cbb99b8_2ace_11eb_af54_fe017cc00077row0_col5" class="data row0 col5" >0.2106</td>
#                         <td id="T_4cbb99b8_2ace_11eb_af54_fe017cc00077row0_col6" class="data row0 col6" >0.4063</td>
#             </tr>
#     </tbody></table>

# %%
prediction_holdout.head()
# Out:
#      LogP      Mol Wt  Num Rotatable Bonds  Aromatic Proportion   logS  \
# 0  4.7181  350.591003                  6.0             0.333333 -5.670
# 1  1.7553  162.279007                  5.0             0.000000 -0.830
# 2  1.6352   78.542000                  1.0             0.000000 -1.470
# 3  2.5724  290.322998                  4.0             0.428571 -4.883
# 4  1.3496  116.160004                  3.0             0.000000 -0.820
#
#      Label
# 0 -5.66108
# 1 -1.80563
# 2 -1.69580
# 3 -3.65982
# 4 -1.36000

# %% [markdown]
# ## **5. Saving Model**

# %%
final_model = finalize_model(tuned_et)
save_model(final_model, './models/solubility/solubilityModel.pkl')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=False, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[], target='logS',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_strategy='...
#                   ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0,
#                                       criterion='mae', max_depth=11,
#                                       max_features=1.0, max_leaf_nodes=None,
#                                       max_samples=None,
#                                       min_impurity_decrease=0.001,
#                                       min_impurity_split=None,
#                                       min_samples_leaf=6, min_samples_split=5,
#                                       min_weight_fraction_leaf=0.0,
#                                       n_estimators=300, n_jobs=-1,
#                                       oob_score=False, random_state=6399,
#                                       verbose=0, warm_start=False)]],
#           verbose=False),
#  './models/solubility/solubilityModel.pkl.pkl')

# %% [markdown]
# ## **6. Model Analysis**

# %% [markdown]
# Further details of the regression plots are available at https://pycaret.org/plot-model/.

# %% [markdown]
# **Residuals Plot**

# %%
plot_model(et, 'residuals')

# %% [markdown]
# **Prediction Error Plot**

# %%
plot_model(et, 'error')

# %% [markdown]
# **Cooks Distance Plot**

# %%
plot_model(et, 'cooks')

# %% [markdown]
# **Recursive Feature Selection**

# %%
plot_model(et, 'rfe')

# %% [markdown]
# **Learning Curve**

# %%
plot_model(et, 'learning')

# %% [markdown]
# **Validation Curve**

# %%
plot_model(et, 'vc')

# %% [markdown]
# **Manifold Learning**

# %%
plot_model(et, 'manifold')

# %% [markdown]
# **Feature Importance**

# %%
plot_model(et, 'feature')

# %% [markdown]
# ### **6.2. Model Interpretaion**
#
# The ``interpret_model()`` function of PyCaret leverages the use of the SHAP library to produce stunning plots for depicting the **SHAP (SHapley Additive exPlanations)** values that was originally proposed by Lundberg and Lee in 2016.$^5$ In a nutshell, SHAP plots adds interpretability to constructed models so that the contribution of each features to the prediction can be elucidated.

# %% [markdown]
# **Summary Plot**

# %%
interpret_model(et)

# %% [markdown]
# **Correlation Plot**

# %%
interpret_model(et, plot = 'correlation')

# %% [markdown]
# **Reason Plot at Observation Level**
#
# The *Reason Plot at Observation Level* as called by PyCaret is better known as the **force plot** and this plot essentially describes the ***push and pull effect*** that each individual features has on the **base value** that eventually leads to the predicted **output value**.

# %%
interpret_model(et, plot = 'reason', observation = 10)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iOVHL343CW5LVGD7037RN'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -3.0334863381022634, "outValue": -3.6014833354949785, "link": "identity", "featureNames": ["LogP", "Mol Wt", "Num Rotatable Bonds", "Aromatic Proportion"], "features": {"0": {"effect": -0.6795150444237231, "value": 3.220599889755249}, "1": {"effect": 0.283523159283778, "value": 194.2740020751953}, "2": {"effect": -0.08665497093630406, "value": 5.0}, "3": {"effect": -0.08535014131646575, "value": 0.4285714328289032}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iOVHL343CW5LVGD7037RN')
#   );
# </script>
